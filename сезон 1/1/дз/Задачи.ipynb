# %% [markdown]
# | Характеристика      | величина                          |
# |---------------------|-----------------------------------|
# | Ограничение времени |	1 секунда                         |
# | Ограничение памяти  | 64Mb                              |
# | Ввод	              | стандартный ввод или input.txt    |
# | Вывод	              | стандартный вывод или output.txt  |
#
# В офисе, где работает программист Петр, установили кондиционер нового типа. Этот кондиционер отличается особой простотой в управлении. У кондиционера есть всего лишь два управляемых параметра: желаемая температура и режим работы.
#
# Кондиционер может работать в следующих четырех режимах:
#
# - «freeze» — охлаждение. В этом режиме кондиционер может только уменьшать температуру. Если температура в комнате и так не больше желаемой, то он выключается.
#
# - «heat» — нагрев. В этом режиме кондиционер может только увеличивать температуру. Если температура в комнате и так не меньше желаемой, то он выключается.
#
# - «auto» — автоматический режим. В этом режиме кондиционер может как увеличивать, так и уменьшать температуру в комнате до желаемой.
#
# - «fan» — вентиляция. В этом режиме кондиционер осуществляет только вентиляцию воздуха и не изменяет температуру в комнате.
#
# Кондиционер достаточно мощный, поэтому при настройке на правильный режим работы он за час доводит температуру в комнате до желаемой.
#
# Требуется написать программу, которая по заданной температуре в комнате troom, установленным на кондиционере желаемой температуре tcond и режиму работы определяет температуру, которая установится в комнате через час.
#
# **Формат ввода**
#
# Первая строка входного файла содержит два целых числа troom, и tcond, разделенных ровно одним пробелом (–50 ≤ troom ≤ 50, –50 ≤ tcond ≤ 50).
#
# Вторая строка содержит одно слово, записанное строчными буквами латинского алфавита — режим работы кондиционера.
#
# **Формат вывода**
#
# Выходной файл должен содержать одно целое число — температуру, которая установится в комнате через час.

# %%
# получение данных
troom, tcond = map(int, input().split(' '))
mode = input()

# выбор режима
if mode == 'freeze':
    print(troom if troom < tcond else tcond)
elif mode == 'heat':
    print(troom if troom > tcond else tcond)
elif mode == 'auto':
    print(tcond)
else:
    print(troom)

# %% [markdown]
# | Характеристика      | величина                          |
# |---------------------|-----------------------------------|
# | Ограничение времени |	1 секунда                         |
# | Ограничение памяти  | 64Mb                              |
# | Ввод	              | стандартный ввод или input.txt    |
# | Вывод	              | стандартный вывод или output.txt  |
#
# Даны три натуральных числа. Возможно ли построить треугольник с такими сторонами. Если это возможно, выведите строку YES, иначе выведите строку NO.
#
# Треугольник — это три точки, не лежащие на одной прямой.

# %%
a, b, c = (int(input()) for i in range(3))

if a + b > c and a + c > b and b + c > a:
    print('YES')
else:
    print('NO')

# %% [markdown]
# | Характеристика      | величина                          |
# |---------------------|-----------------------------------|
# | Ограничение времени |	1 секунда                         |
# | Ограничение памяти  | 64Mb                              |
# | Ввод	              | стандартный ввод или input.txt    |
# | Вывод	              | стандартный вывод или output.txt  |
#
# Телефонные номера в адресной книге мобильного телефона имеют один из следующих форматов: +7<код><номер>, 8<код><номер>, <номер>, где <номер> — это семь цифр, а <код> — это три цифры или три цифры в круглых скобках. Если код не указан, то считается, что он равен 495. Кроме того, в записи телефонного номера может стоять знак “-” между любыми двумя цифрами (см. пример). На данный момент в адресной книге телефона Васи записано всего три телефонных номера, и он хочет записать туда еще один. Но он не может понять, не записан ли уже такой номер в телефонной книге. Помогите ему! Два телефонных номера совпадают, если у них равны коды и равны номера. Например, +7(916)0123456 и 89160123456 — это один и тот же номер.
#
# Формат ввода
# В первой строке входных данных записан номер телефона, который Вася хочет добавить в адресную книгу своего телефона. В следующих трех строках записаны три номера телефонов, которые уже находятся в адресной книге телефона Васи. Гарантируется, что каждая из записей соответствует одному из трех приведенных в условии форматов.
#
# Формат вывода
# Для каждого телефонного номера в адресной книге выведите YES (заглавными буквами), если он совпадает с тем телефонным номером, который Вася хочет добавить в адресную книгу или NO (заглавными буквами) в противном случае.

# %%
from re import split

def cast(number: str) -> str:
    if number[0] == '+':
        number = number[2:]
    elif number[0] == '8':
        number = number[1:]
    
    new_number = ''.join(split("-|\)|\(", number))
    if len(new_number) < 10:
        new_number = '495' + new_number
    
    return new_number

pattern = input()
pattern = cast(pattern)

for i in range(3):
    phone_from_book = input()
    phone_from_book = cast(phone_from_book)

    
    print(f'\t{pattern} <-> {phone_from_book}')
    
    if phone_from_book == pattern:
        print('YES')
    else:
        print('NO')

# %% [markdown]
# | Характеристика      | величина                          |
# |---------------------|-----------------------------------|
# | Ограничение времени |	1 секунда                         |
# | Ограничение памяти  | 64Mb                              |
# | Ввод	              | стандартный ввод или input.txt    |
# | Вывод	              | стандартный вывод или output.txt  |
#
#
# Решите в целых числах уравнение:
#
# $$\sqrt{ax+b} = c$$
#
# a, b, c – данные целые числа: найдите все решения или сообщите, что решений в целых числах нет.

# %%
def print_sol(a, b, c): #линейное ур
	def print_x(x):
		int_x = int(x)
		if int_x == x:
			print(int_x)
		else:
			print("NO SOLUTION")

	if c < 0:
		print("NO SOLUTION")
	elif c == 0:
		if a == 0:
			if b == 0:
				print("MANY SOLUTIONS")
			else:
				print("NO SOLUTION")
		else:
			if b == 0:
				print_x(0)
			else:
				print_x(-b/a)
	else:
		if a == 0:
			if b == 0:
				print("NO SOLUTION")
			else:
				if c*c == b:
					print("MANY SOLUTIONS")
				else:
					print("NO SOLUTION")
		else:
			if b == 0:
				print_x(c*c/a)
			else:
				print_x((c*c - b)/a)

def read_int():
	return int(input())


a = read_int()
b = read_int()
c = read_int()
print_sol(a, b, c)

# %% [markdown]
# | Характеристика      | величина                          |
# |---------------------|-----------------------------------|
# | Ограничение времени |	1 секунда                         |
# | Ограничение памяти  | 64Mb                              |
# | Ввод	              | стандартный ввод или input.txt    |
# | Вывод	              | стандартный вывод или output.txt  |
#
# Бригада скорой помощи выехала по вызову в один из отделенных районов. К сожалению, когда диспетчер получил вызов, он успел записать только адрес дома и номер квартиры K1, а затем связь прервалась. Однако он вспомнил, что по этому же адресу дома некоторое время назад скорая помощь выезжала в квартиру K2, которая расположена в подъезда P2 на этаже N2. Известно, что в доме M этажей и количество квартир на каждой лестничной площадке одинаково. Напишите программу, которая вычисляет номер подъезда P1 и номер этажа N1 квартиры K1.
#
# Формат ввода
# Во входном файле записаны пять положительных целых чисел K1, M, K2, P2, N2. Все числа не превосходят 106.
#
# Формат вывода
# Выведите два числа P1 и N1. Если входные данные не позволяют однозначно определить P1 или N1, вместо соответствующего числа напечатайте 0. Если входные данные противоречивы, напечатайте два числа –1 (минус один).

# %%
"""
    k1 - номер квартиры
    m  - кол-во этажей в доме
    k2 - номер известной квартиры
    p2 - подъезд известной квартиры
    n2 - этаж известной квартиры
    
    Идея, т.к. у нас числа до милиона, мы можем перебрать параметр кол-во квартир на этаже.
    
    ЧЕРНОВИК
"""

import math

test = 1000

room1, floors, room2, entrance2, floor2 = map(int, input().split(' '))

# проверка противоречивости
if not (math.ceil(room2 / floor2) * floors * entrance2 >= room2 > math.ceil(room2 / floor2) * floors * (entrance2 - 1)):
    print("INPUT ERROR!")

entrance1 = []
floor1 = []

for rooms_on_floor in range(1, test):   # перебираем параметр кол-во квартир на этаж
    
    if rooms_on_floor * floor2 >= room2 > rooms_on_floor * (floor2 - 1):
        # номер второй квартиры, находится на нужном этаже
        
        total_rooms_on_entrance = rooms_on_floor * floors  # кол-во квартир в подъезде
        
        # t_entr - кол-во пройденных подъездов 
        # t_new_number_room_1 - относительный номер (room1) в новом подъезде
        t_entr, new_number_room_1 = divmod(room1, total_rooms_on_entrance)
        t_fl1 = new_number_room_1 / rooms_on_floor   
        
        if t_fl1 == 0:          
            entrance1.append(t_entr)  # отсчет от первого
            floor1.append(floors)  # этаж не дробное число
        else:
            entrance1.append(t_entr + 1)  # отсчет от первого
            floor1.append(math.ceil(t_fl1))  # этаж не дробное число
            
            
# все хорошо, мы отыскали ровно один ответ, все определено
print(entrance1)
print(floor1)
print(test, len(floor1), len(entrance1))

print(len(set(entrance1)), len(set(floor1)))


if (len(entrance1) == 1 and len(floor1) == 1):
    print(*entrance1, *floor1)
elif len(set(entrance1)) == 1:
    print(entrance1[0], 0)
elif len(set(floor1)) == 1:
    print(0, floor1[0])
else:
    print(-1, -1)

# %%
import math

def validate(floors, room2, entrance2, floor2):
    if floors == 0 or room2 == 0 or entrance2 == 0 or floor2 == 0:
        return False
    
    if floor2 > floors:
        return False
    
    # проверка на корректность входных параметров:
    # квартира №2 должна находиться в своем подъезде и этаже
    rooms_on_floor =  math.ceil(room2 / floor2)
    rooms_on_entrance = rooms_on_floor * floors
    if not (rooms_on_entrance * entrance2 >= room2 > rooms_on_entrance * (entrance2 - 1)) or not (rooms_on_floor * floor2 >= room2 > rooms_on_floor * (floor2 - 1)):
        return False
    return True

def run(room1, floors, room2, entrance2, floor2):
    if not validate(floors, room2, entrance2, floor2):
        return (-1, -1)
    
    entrance1 = []
    floor1 = []

    for rooms_on_floor in range(1, 1_000):   # перебираем параметр кол-во квартир на этаж
        
        if rooms_on_floor * floor2 >= room2 > rooms_on_floor * (floor2 - 1):
            # номер второй квартиры, находится на нужном этаже
            
            total_rooms_on_entrance = rooms_on_floor * floors  # кол-во квартир в подъезде
            
            # t_entr - кол-во пройденных подъездов 
            # t_new_number_room_1 - относительный номер (room1) в новом подъезде
            t_entr, new_number_room_1 = divmod(room1, total_rooms_on_entrance)
            t_fl1 = new_number_room_1 / rooms_on_floor   
            
            if t_fl1 == 0:          
                entrance1.append(t_entr)  # отсчет от первого
                floor1.append(floors)  # этаж не дробное число
            else:
                entrance1.append(t_entr + 1)  # отсчет от первого
                floor1.append(math.ceil(t_fl1))  # этаж не дробное число
                
    if (len(entrance1) == 1 and len(floor1) == 1):
        return (*entrance1, *floor1)
    
    if len(set(entrance1)) == 1:
        return (entrance1[0], 0)
    
    if len(set(floor1)) == 1:
        return (0, floor1[0])
    
    return (-1, -1)



if __name__ == '__main__':
    room1, floors, room2, entrance2, floor2 = map(int, input().split(' '))
    print(*run(room1, floors, room2, entrance2, floor2))

# %% [markdown]
# Третья попытка

# %%
import math

def run(room1, floors, room2, entrance2, floor2):
    def validate_bounds():
        # Проверка, что все значения только положительные числа
        if (room1 > 0 and floors > 0 
            and room2  > 0 and entrance2  > 0 
            and floor2 > 0 and floor2 <= room2):
            return True
        return False 
    
    def validate_floor(rooms_on_floor_start, rooms_on_floor_stop):
        for rooms_on_floor in range(rooms_on_floor_start, rooms_on_floor_stop + 1):
            if rooms_on_floor * floor2 >= room2 > rooms_on_floor * (floor2 - 1):
                return True
        return False
    
    def validate_entrance(rooms_on_floor_start, rooms_on_floor_stop):
        for rooms_on_floor in range(rooms_on_floor_start, rooms_on_floor_stop + 1):
            
            rooms_on_entrance = rooms_on_floor * floors
            
            if rooms_on_entrance * entrance2 >= room2 > rooms_on_entrance * (entrance2 - 1):
                return True
        return False
    
    def left_bound():
        # бинарный поиск левой границы нужного числа квартир на этаже
        left_v = 1
        right_v = 1_000_000
        
        while right_v - left_v > 1:
            mid_v = (right_v + left_v) // 2
            if math.ceil(room2 / mid_v) > floor2:
                left_v = mid_v
            else:
                right_v = mid_v
        return right_v


    def right_bound():
        # бинарный поиск правой границы нужного числа квартир на этаже
        left_v = 1
        right_v = 1_000_000
        
        while right_v - left_v > 1:
            mid_v = (right_v + left_v) // 2
            if math.ceil(room2 / mid_v) >= floor2:
                left_v = mid_v
            else:
                right_v = mid_v
        return left_v
    
    # инициализируем границы поиска
    rooms_on_floor_start = left_bound()
    rooms_on_floor_stop = right_bound()
    
    if (not validate_bounds() 
        or not validate_floor(rooms_on_floor_start, rooms_on_floor_stop) 
        or not validate_entrance(rooms_on_floor_start, rooms_on_floor_stop)):
        
        # не прошли валидацию и корректность входных данных
        return -1, -1
    
    # инициализируем массивы данных
    entrance1 = set()
    floor1 = set()
    
    
    for rooms_on_floor in range(rooms_on_floor_start, rooms_on_floor_stop + 1):
        # перебираем все допустимые значения этажей
        
        total_rooms_on_entrance = rooms_on_floor * floors  # кол-во квартир в подъезде
            
        # t_entr - кол-во пройденных подъездов 
        # t_new_number_room_1 - относительный номер (room1) в новом подъезде
        t_entr, new_number_room_1 = divmod(room1, total_rooms_on_entrance)
        t_fl1 = new_number_room_1 / rooms_on_floor   
        
        if t_fl1 == 0:          
            entrance1.add(t_entr)  # отсчет от первого
            floor1.add(floors)  # этаж не дробное число
        else:
            entrance1.add(t_entr + 1)  # отсчет от первого
            floor1.add(math.ceil(t_fl1))  # этаж не дробное число
    
    if (len(entrance1) == 1 and len(floor1) == 1):
        return entrance1.pop(), floor1.pop()
    
    if len(set(entrance1)) == 1:
        return entrance1.pop(), 0
    
    if len(set(floor1)) == 1:
        return 0, floor1.pop()
    
    return -1, -1


if __name__ == '__main__':
    room1, floors, room2, entrance2, floor2 = map(int, input().split(' '))
    print(*run(room1, floors, room2, entrance2, floor2), sep='\n')

# %%
"""
    РАБОТАЕТ
    k1 - номер квартиры
    m  - кол-во этажей в доме
    k2 - номер известной квартиры
    p2 - подъезд известной квартиры
    n2 - этаж известной квартиры
    
    Идея, т.к. у нас числа до милиона, мы можем перебрать параметр кол-во квартир на этаже.
"""

import math

k1, m, k2, p2, n2 = map(int, input().split(' ')) # считываем параметры

arr_p1 = set()
arr_n1 = set()

# тупой перевод "кол-ва квартир на этаже"
for ck in range(1, 10**6):               # ck - кол-во квартир на этаже
    ckp = ck * m                         # ckp - кол-во квартир в подъезде
    
    tp2 = ((k2-1) // ckp) + 1           # tp2 - предпологаемый подъезд для кв2
    tk2 = k2 - (tp2 - 1) * ckp           # tk2 - предпологаемый номер квартиры
    tn2 = ((tk2-1) // ck) + 1            # tn2 - предполагаемый этаж квартиры
    
    if (tn2 == n2) and (tp2 == p2):      # совпадают этаж и подъезд, значит верно подобрали
        p1 = ((k1-1) // ckp) + 1         # p1 - номер подъезда
        tk1 = k1 - (p1 - 1) * ckp        # относительный номер квартиры в подъезде
        n1 = ((tk1-1) // ck) + 1         # этаж

        arr_p1.add(p1)
        arr_n1.add(n1)
        

lp, ln = len(arr_p1), len(arr_n1)

if lp == 1:
    print(arr_p1.pop(), end=' ')
elif lp == 0:
    print(-1, end=' ')
elif lp > 0:
    print(0, end=' ')
    
if ln == 1:
    print(arr_n1.pop())
elif ln == 0:
    print(-1)
elif ln > 0:
    print(0)

# %% [markdown]
# В школе решили на один прямоугольный стол поставить два прямоугольных ноутбука. Ноутбуки нужно поставить так, чтобы их стороны были параллельны сторонам стола. Определите, какие размеры должен иметь стол, чтобы оба ноутбука на него поместились, и площадь стола была минимальна.
#
# Формат ввода
# Вводится четыре натуральных числа, первые два задают размеры одного ноутбука, а следующие два — размеры второго. Числа не превышают 1000.
#
# Формат вывода
# Выведите два числа — размеры стола. Если возможно несколько ответов, выведите любой из них (но только один).

# %%
def area(point: tuple):
    return point[0] * point[1]

def point_min(points: list) -> tuple:
    ans = points[0]
    ans_area = area(points[0])
    
    for p in points:
        cur_area = area(p)
        if cur_area <= ans_area:
            ans_area = cur_area
            ans = p
    
    return ans
    

a1, b1, a2, b2 = map(int, input().split(' '))

p1 = (b1 + b2, max(a1, a2))
p2 = (a1 + a2, max(b1, b2))
p3 = (b1 + a2, max(a1, b2))
p4 = (a1 + b2, max(a2, b1))

print(*point_min([p1, p2, p3, p4]))

# %% [markdown]
# Имеется N кг металлического сплава. Из него изготавливают заготовки массой K кг каждая. После этого из каждой заготовки вытачиваются детали массой M кг каждая (из каждой заготовки вытачивают максимально возможное количество деталей). Если от заготовок после этого что-то остается, то этот материал возвращают к началу производственного цикла и сплавляют с тем, что осталось при изготовлении заготовок. Если того сплава, который получился, достаточно для изготовления хотя бы одной заготовки, то из него снова изготавливают заготовки, из них – детали и т.д. Напишите программу, которая вычислит, какое количество деталей может быть получено по этой технологии из имеющихся исходно N кг сплава.

# %%
def run(n, k, m):
    count = 0
    cm, lk = divmod(k, m)
    while (n >= k):
        ck, n = divmod(n, k)       
        
        count += ck * cm
        n += ck * lk
    
    return count

n, k, m = map(int, input().split(' '))
print(run(n, k, m))
# Out:
# 4
